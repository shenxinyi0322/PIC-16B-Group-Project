# %%
import pandas as pd

# %%
df = pd.read_excel("CB-Insights_Global-Unicorn-Club_2022.xlsx")

# %%
df
# Out:
#       Unnamed: 0  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1202         NaN
# 1203         NaN
# 1204         NaN
# 1205         NaN
# 1206         NaN
#
#      Global Unicorn Club: Private Companies Valued at $1B+\n(as of December 31st, 2022)  \
# 0                                                   NaN
# 1                                               Company
# 2                                             ByteDance
# 3                                                SpaceX
# 4                                                 SHEIN
# ...                                                 ...
# 1202                                           Zhaogang
# 1203                                        Zhuan Zhuan
# 1204                                           Zihaiguo
# 1205                                               Zopa
# 1206                                              Zwift
#
# ...

# %%
new_header = df.iloc[1] #grab the first row for the header
df = df[2:] #take the data less the header row
df.columns = new_header

# %%
df = df.dropna(axis=1, how='all')

# %%
df.to_csv('crunchbase_data.csv', index=False)

# %%
df
# Out:
# 1         Company Valuation ($B)          Date Joined         Country  \
# 2       ByteDance            140  2017-04-07 00:00:00           China
# 3          SpaceX            127  2012-12-01 00:00:00   United States
# 4           SHEIN            100  2018-07-03 00:00:00           China
# 5          Stripe             95  2014-01-23 00:00:00   United States
# 6           Canva             40  2018-01-08 00:00:00       Australia
# ...           ...            ...                  ...             ...
# 1202     Zhaogang              1  2017-06-29 00:00:00           China
# 1203  Zhuan Zhuan              1  2017-04-18 00:00:00           China
# 1204     Zihaiguo              1  2021-05-06 00:00:00           China
# 1205         Zopa              1  2021-10-19 00:00:00  United Kingdom
# 1206        Zwift              1  2020-09-16 00:00:00   United States
#
# 1              City                         Industry  \
# 2           Beijing          Artificial intelligence
# ...

# %%
name =  list(df["Company"])
# Out:
# ['ByteDance',
#  'SpaceX',
#  'SHEIN',
#  'Stripe',
#  'Canva',
#  'Checkout.com',
#  'Instacart',
#  'Databricks',
#  'Revolut',
#  'Epic Games',
#  'Fanatics',
#  'Chime',
#  "BYJU's",
#  'J&T Express',
#  'Xiaohongshu',
#  'Miro',
#  'Yuanfudao',
#  'Discord',
#  'DJI Innovations',
#  'goPuff',
#  'Ripple',
#  'Yuanqi Senlin',
#  'Blockchain.com',
#  'Plaid',
#  'OpenSea',
#  'Celonis',
#  'Grammarly',
#  'Devoted Health',
#  'Faire',
#  'Brex',
#  'Biosplice Therapeutics',
#  'Bitmain Technologies',
#  'Deel',
#  'GoodLeap',
#  'JUUL Labs',
#  'Xingsheng Selected',
#  'Getir',
#  'Airtable',
#  'ZongMu Technology',
#  'Rippling',
#  'Global Switch',
#  'Bolt',
#  'Weilong',
#  'Swiggy',
#  'Alchemy',
#  'Chehaoduo',
#  'Digital Currency Group',
#  'Gusto',
#  'KuCoin',
#  'Lalamove',
#  'Notion Labs',
#  'reddit',
#  'Talkdesk',
#  'Thrasio',
#  'OutSystems',
#  'ServiceTitan',
#  'HEYTEA',
#  'N26',
#  'Klaviyo',
#  'TripActions',
#  'Northvolt',
#  'Niantic',
#  'OYO Rooms',
# ...

# %%
string = 'crunchbase '

# %%
name = [ string + s for s in name]
