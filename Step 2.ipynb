# %%
import pandas as pd
import numpy as np
import sqlite3

# read the csv file
df = pd.read_csv('unicorn.csv')

# change all company name into lower case for web scraping
df["urlsub"]=df["Company"].str.lower()

# drop NaN values in the dataframe
df = df.dropna(axis=0,how='all')
df = df.dropna(axis=1,how='all')
#df.to_csv('unicorn.csv', index=False)
country_list = df.Country.unique()
print(country_list)

df = df[['urlsub']]
df
# Out:
# ['China' 'United States' 'Australia' 'United Kingdom' 'India' 'Indonesia'
#  'Germany' 'Turkey' 'Seychelles' 'Hong Kong' 'Sweden' 'Mexico' 'Estonia'
#  'Israel' 'Canada' 'South Korea' 'Netherlands' 'France' 'Finland'
#  'Belgium' 'Colombia' 'Brazil' 'Denmark' 'Switzerland' 'Lithuania'
#  'Austria' 'Ireland' 'Singapore' 'Vietnam' 'United Arab Emirates'
#  'Argentina' 'Spain' 'Philippines' 'Luxembourg' 'Nigeria' 'Japan'
#  'Croatia' 'Malaysia' 'Senegal' 'Bermuda' 'South Africa' 'Thailand'
#  'Norway' 'Ecuador' 'Chile' 'Czech Republic' 'London' 'Liechtenstein'
#  'Italy']
#            urlsub
# 0       bytedance
# 1          spacex
# 2           shein
# 3          stripe
# 4           canva
# ...           ...
# 1200     zhaogang
# 1201  zhuan zhuan
# 1202     zihaiguo
# 1203         zopa
# 1204        zwift
#
# [1205 rows x 1 columns]

# %%
for i in range(len(df)):
    print(df.iloc[i,0])
# Out:
# bytedance
# spacex
# shein
# stripe
# canva
# checkout.com
# instacart
# databricks
# revolut
# epic games
# fanatics
# chime
# byju's
# j&t express
# xiaohongshu
# miro
# yuanfudao
# discord
# dji innovations
# gopuff
# ripple
# yuanqi senlin
# blockchain.com
# plaid
# opensea
# celonis
# grammarly
# devoted health
# faire
# brex
# biosplice therapeutics
# bitmain technologies
# deel
# goodleap
# juul labs
# xingsheng selected
# getir
# airtable
# zongmu technology
# rippling
# global switch
# bolt
# weilong
# swiggy
# alchemy
# chehaoduo
# digital currency group
# gusto
# kucoin
# lalamove
# notion labs
# reddit
# talkdesk
# thrasio
# outsystems
# servicetitan
# heytea
# n26
# klaviyo
# tripactions
# northvolt
# niantic
# oyo rooms
# tanium
# rapyd
# kavak
# chainalysis
# nuro
# personio
# pony.ai
# sumup
# anduril
# bolt
# lacework
# tipalti
# ramp
# tempus
# dream11
# falconx
# fireblocks
# flexport
# starkware
# caris life sciences
# hopin
# dapper labs
# automattic
# netskope
# ...
